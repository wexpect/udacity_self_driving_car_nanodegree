# %% [markdown]
# # Exercise 2 - Custom training loop
#
# ## Objective
#
# In this exercise, you have to implement your first training and validation loops from scratch to train
# the logistic model you implemented. To do so, you will also have to create an optimizer.
#
# ## Details
#
# A training loop goes through element of the training dataset and uses it to update the model's weights.
# A validation loop goes through each element of the validation dataset and uses it to calculate
# the metrics (eg, accuracy). We call **epoch** an iteration of one training loop and one validation loop.
#
# The input to your model should be normalized. You can do this by dividing them by 255: `X /= 255`.
#
# You can run `python training.py` to train your first machine learning model!
#
# You will need to specify the `--imdir`, e.g. `--imdir GTSRB/Final_Training/Images/`, using the provided GTSRB dataset.
#
# ## Tips
#
# You don't need `tf.GradientTape` for the validation loop as you will not be updating gradients.
#
# The `assign_sub` Variable method will be useful to perform the weights update in the sgd optimizer.
#
# Use the `tf.one_hot` function to get the one vector from the ground truth label.

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

imdir = 'GTSRB/Final_Training/Images'
train_dataset = image_dataset_from_directory(
    imdir,
    image_size=(32, 32),
#     batch_size=256,
    batch_size=256,    
    validation_split=0.1,
    subset='training',
    seed=123
)
# Out:
# Found 4300 files belonging to 43 classes.
# Using 3870 files for training.

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((None, 32, 32, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
i = 0
for X, Y in train_dataset:
    i += 1
    print('\n\nround {}'.format(i))
    print(X)
    print('\n\n')
    print(Y)
# Out:
# round 1
# tf.Tensor(
# [[[[ 47.664062   40.226562   44.382812 ]
#    [ 31.646484   31.34375    21.612305 ]
#    [ 42.216797   41.404297   41.20117  ]
#    ...
#    [ 43.308594   54.043945   62.960938 ]
#    [ 46.23047    64.118164   76.06445  ]
#    [ 15.2734375  27.476562   35.039062 ]]
#
#   [[ 44.64453    37.566406   39.36328  ]
#    [ 33.229492   32.995117   21.805664 ]
#    [ 38.597656   38.2041     36.765625 ]
#    ...
#    [ 70.97754    83.24121    88.850586 ]
#    [ 58.848633   78.038086   87.98047  ]
#    [ 15.87793    27.146484   34.515625 ]]
#
#   [[ 44.478516   38.041016   36.092773 ]
#    [ 53.617188   54.958984   42.20996  ]
#    [ 36.84961    36.646484   34.316406 ]
#    ...
#    [ 78.73047    93.69238    93.44238  ]
#    [ 26.042969   45.05957    52.137695 ]
#    [ 11.983398   23.11914    29.524414 ]]
#
#   ...
#
#   [[ 22.182617   19.426758   24.71875  ]
#    [ 17.141602   17.014648   19.205078 ]
#    [ 17.78125    18.1875     17.654297 ]
#    ...
#    [ 23.038086   27.038086   28.038086 ]
#    [ 33.527344   37.527344   38.152344 ]
#    [ 24.166992   28.166992   28.791992 ]]
#
#   [[ 14.893555   20.143555   22.831055 ]
#    [ 18.745117   20.84375    24.47754  ]
#    [ 15.203125   15.936523   18.625    ]
#    ...
#    [ 21.546875   25.546875   24.546875 ]
#    [ 31.0625     36.0625     32.01367  ]
#    [ 19.433594   24.433594   19.808594 ]]
#
#   [[ 14.830078   22.830078   24.830078 ]
#    [ 16.40625    20.40625    23.40625  ]
#    [ 16.203125   16.796875   21.       ]
#    ...
#    [ 18.265625   22.265625   21.265625 ]
#    [ 32.875      37.875      33.71875  ]
#    [ 20.401367   25.401367   19.401367 ]]]
#
#
#  [[[ 31.         25.         35.       ]
#    [ 24.5        19.3125     26.875    ]
#    [ 27.125      23.5        30.5      ]
#    ...
#    [ 30.         30.         30.625    ]
#    [ 30.         30.         32.       ]
#    [ 30.         30.         32.       ]]
#
#   [[ 36.359375   28.828125   39.59375  ]
#    [ 32.969727   26.250977   34.5791   ]
#    [ 44.208008   39.051758   45.76465  ]
#    ...
#    [ 30.         30.         30.625    ]
#    [ 30.         30.         32.       ]
#    [ 30.         30.         32.       ]]
#
#   [[ 39.21875    28.78125    39.171875 ]
#    [ 36.286133   26.661133   35.109375 ]
#    [ 58.42578    50.36328    56.569336 ]
#    ...
#    [ 30.         30.         31.46289  ]
#    [ 30.         30.         32.       ]
#    [ 30.         30.         32.       ]]
#
#   ...
#
#   [[ 76.171875   60.171875   63.171875 ]
#    [ 80.51367    65.32617    69.95117  ]
#    [ 72.5459     60.9834     68.0459   ]
#    ...
#    [ 36.118164   31.921875   27.424805 ]
#    [ 40.146484   33.098633   29.78125  ]
#    [ 43.21875    35.21875    32.21875  ]]
#
#   [[ 78.9375     62.9375     65.46875  ]
#    [ 87.01172    71.82422    75.98047  ]
#    [ 82.64453    71.08203    77.99805  ]
#    ...
#    [ 34.703125   30.916992   26.625    ]
#    [ 37.57129    32.140625   28.518555 ]
#    [ 41.0625     33.765625   30.765625 ]]
#
#   [[ 82.         66.         67.       ]
#    [ 92.5625     77.375      80.       ]
#    [ 90.875      79.3125     85.75     ]
#    ...
#    [ 33.9375     29.625      26.625    ]
#    [ 36.375      31.375      28.375    ]
#    [ 38.         33.         30.       ]]]
#
#
#  [[[ 21.015625   25.015625   26.015625 ]
#    [ 26.264893   30.264893   31.264893 ]
#    [ 30.34253    34.34253    35.34253  ]
#    ...
#    [ 16.         16.         16.       ]
#    [ 16.         16.         16.       ]
#    [ 16.         16.         16.       ]]
#
#   [[ 18.4375     22.4375     23.4375   ]
#    [ 23.691895   27.691895   28.691895 ]
#    [ 28.25       32.25       33.25     ]
#    ...
#    [ 16.         16.         16.       ]
#    [ 16.         16.         16.       ]
#    [ 16.         16.         16.       ]]
#
#   [[ 19.689941   23.689941   24.689941 ]
#    [ 22.851074   26.851074   27.851074 ]
#    [ 25.302979   29.302979   30.302979 ]
#    ...
#    [ 16.         16.         16.       ]
#    [ 16.         16.         16.       ]
#    [ 16.         16.         16.       ]]
#
#   ...
#
#   [[ 18.8125     17.8125     13.8125   ]
#    [ 20.359375   19.359375   15.359375 ]
#    [ 22.25       21.25       17.25     ]
#    ...
#    [ 13.         12.          8.       ]
#    [ 13.199463   12.199463    8.199463 ]
#    [ 14.1875     13.1875      9.1875   ]]
#
#   [[ 18.109375   17.109375   13.109375 ]
#    [ 19.466553   18.466553   14.466553 ]
#    [ 21.284912   20.284912   16.284912 ]
#    ...
#    [ 13.578125   12.578125    8.578125 ]
#    [ 14.25       13.25        9.25     ]
#    [ 14.953857   13.953857    9.953857 ]]
#
#   [[ 17.25       16.25       12.25     ]
#    [ 18.750732   17.750732   13.750732 ]
#    [ 20.153809   19.153809   15.153809 ]
#    ...
#    [ 14.469971   13.469971    9.469971 ]
#    [ 14.094482   13.094482    9.094482 ]
#    [ 14.140625   13.140625    9.140625 ]]]
#
#
#  ...
#
#
#  [[[100.08203    93.08203    87.08203  ]
#    [106.35156   101.03906    97.34619  ]
#    [129.26758   125.10986   123.51904  ]
#    ...
#    [ 70.867676   61.683105   40.106445 ]
#    [ 81.58496    71.16846    48.66797  ]
#    [ 86.14746    79.072754   53.296875 ]]
#
#   [[120.5459    115.7124    107.99414  ]
#    [ 65.65967    60.59619    54.938965 ]
#    [146.35254   141.75879   138.45068  ]
#    ...
#    [ 73.04492    63.26367    42.85742  ]
#    [ 75.65723    65.12598    42.969727 ]
#    [ 92.989746   85.13574    61.697754 ]]
#
#   [[155.03125   151.03125   141.375    ]
#    [ 96.11084    92.11084    82.45459  ]
#    [123.26416   119.13818   112.42676  ]
#    ...
#    [ 76.36572    65.79492    47.716797 ]
#    [ 77.12305    66.5918     46.435547 ]
#    [ 76.023926   68.023926   46.058105 ]]
#
#   ...
#
#   [[ 58.54541    51.54541    45.16748  ]
#    [ 56.20996    49.20996    41.3125   ]
#    [ 58.60205    51.60205    42.78955  ]
#    ...
#    [ 35.046875   36.3125     31.242676 ]
#    [ 33.94873    35.515625   31.649414 ]
#    [ 31.984375   32.984375   27.984375 ]]
#
#   [[ 59.1875     52.1875     43.78125  ]
#    [ 52.719727   45.719727   37.65625  ]
#    [ 52.08252    45.691895   37.48877  ]
#    ...
#    [ 29.015625   32.32373    29.336914 ]
#    [ 28.45459    31.767578   30.048828 ]
#    [ 30.385254   31.609375   26.911621 ]]
#
#   [[ 52.01709    47.220215   37.95459  ]
#    [ 48.083008   43.286133   34.46875  ]
#    [ 44.09082    40.825195   31.825195 ]
#    ...
#    [ 33.19873    34.9375     29.796875 ]
#    [ 30.864258   31.858887   27.307129 ]
#    [ 36.166992   36.226074   29.45166  ]]]
#
#
#  [[[209.96191   201.71777   107.25     ]
#    [246.35059   241.61914   158.86133  ]
#    [229.41309   224.81055   124.08789  ]
#    ...
#    [114.29492   118.930664   70.62012  ]
#    [101.75293   119.12891    81.31543  ]
#    [111.66016   125.53516    87.47266  ]]
#
#   [[215.17188   195.87402   147.75293  ]
#    [238.22559   221.40723   166.81738  ]
#    [245.54199   237.65039   152.10742  ]
#    ...
#    [210.16309   207.22363   144.6377   ]
#    [225.38965   221.95801   177.11426  ]
#    [222.6211    217.8711    172.08984  ]]
#
#   [[234.79199   208.33008   203.88477  ]
#    [254.37012   248.32715   214.44336  ]
#    [253.85156   246.2207    170.15234  ]
#    ...
#    [245.53418   242.57812   168.89941  ]
#    [254.4873    249.89062   191.49414  ]
#    [222.08984   205.13672   143.61914  ]]
#
#   ...
#
#   [[136.60742   116.18848    77.456055 ]
#    [126.4541    119.13867    73.12695  ]
#    [144.39941   136.72949    83.5293   ]
#    ...
#    [137.04102   153.19531    94.166016 ]
#    [167.28613   168.61914   108.82324  ]
#    [160.84961   162.95215   101.30957  ]]
#
#   [[144.06055   101.28027    46.543945 ]
#    [127.86426   115.59277    58.70215  ]
#    [114.049805  125.76758    71.62207  ]
#    ...
#    [124.48242   118.259766   56.67578  ]
#    [141.99707   138.1748     67.97461  ]
#    [138.64941   134.58594    62.680664 ]]
#
#   [[176.63965   152.22559    98.54785  ]
#    [205.81934   195.91309   137.97559  ]
#    [213.5127    216.33984   156.20508  ]
#    ...
#    [ 99.71289    98.56543    46.94043  ]
#    [114.41992   117.21582    56.762695 ]
#    [167.61035   169.40234   107.46387  ]]]
#
#
#  [[[ 84.748535   84.748535   86.748535 ]
#    [ 82.808105   82.808105   84.808105 ]
#    [ 83.671875   83.671875   85.671875 ]
#    ...
#    [ 50.953125   46.953125   45.953125 ]
#    [ 51.67627    47.67627    46.67627  ]
#    [ 51.71875    47.71875    46.71875  ]]
#
#   [[114.339355  115.058105  119.19873  ]
#    [112.18506   112.90381   117.04443  ]
#    [113.171875  113.890625  118.03125  ]
#    ...
#    [ 73.734375   73.59375    73.3125   ]
#    [ 71.29932    71.15869    70.87744  ]
#    [ 70.28125    70.140625   69.859375 ]]
#
#   [[145.06982   146.06982   151.06982  ]
#    [143.0625    144.0625    149.0625   ]
#    [143.26025   144.26025   149.26025  ]
#    ...
#    [ 94.734375   95.734375   97.734375 ]
#    [ 92.03125    93.03125    95.03125  ]
#    [ 89.328125   90.328125   92.328125 ]]
#
#   ...
#
#   [[159.        166.        172.       ]
#    [159.        166.        172.       ]
#    [159.        166.        172.       ]
#    ...
#    [159.19238   170.66113   177.12988  ]
#    [150.42822   161.89697   168.36572  ]
#    [138.73975   149.5293    158.44287  ]]
#
#   [[159.03125   166.03125   172.03125  ]
#    [157.        164.        170.       ]
#    [159.84375   166.84375   172.84375  ]
#    ...
#    [113.45361   126.45361   134.45361  ]
#    [115.68652   130.1084    139.15527  ]
#    [118.316895  135.32129   145.32129  ]]
#
#   [[159.0752    166.0752    172.0752   ]
#    [159.04688   166.04688   172.04688  ]
#    [159.81152   166.81152   172.81152  ]
#    ...
#    [113.55078   126.70703   135.70703  ]
#    [ 79.08447    96.17822   106.36572  ]
#    [ 92.53125   111.535645  125.581055 ]]]], shape=(256, 32, 32, 3), dtype=float32)
#
#
#
# tf.Tensor(
# [24 33 42  5 28 14 42 25 33 16 28  0 31 33 26 41 20 20 29 42 40 24  3 39
#   8  1 12 22 28 16 17 38 23  0 40  0 23 28  4 35 29  9  5 23 22  5 17 18
#  28 29 26 23 42  9 11  8 40  1 31 13 16 39 10  8 35 14 32 31  7 39 42 38
#  14  0 29 22 32 33 21 33 38 16  9 36 15 27 42 35 38 32 14 28 27  9 39 37
#  27 19 39 33 41 33 40 20 13 31 29 12  8  8 34 32 27 23  3 30 27 33  2 12
#    [ 29.         28.         26.       ]
#    [ 29.         28.         26.       ]
#    [ 29.         28.         26.       ]]
#
#   [[ 31.296875   26.765625   22.53125  ]
#    [ 31.883057   27.351807   23.117432 ]
#    [ 32.671875   28.140625   23.90625  ]
#    ...
#    [ 28.765625   28.         26.       ]
#    [ 28.765625   28.         26.       ]
#    [ 28.765625   28.         26.       ]]
#
#   [[ 29.         26.         21.       ]
#    [ 29.         26.         21.       ]
#    [ 29.609375   26.609375   21.609375 ]
#    ...
#    [ 28.         28.         26.       ]
#    [ 28.         28.         26.       ]
#    [ 28.         28.         26.       ]]]
#
#
#  [[[ 45.14453    54.14453    49.902344 ]
#    [ 31.621094   41.621094   32.95703  ]
#    [ 47.23828    58.23828    42.73828  ]
#    ...
#    [ 95.55078   100.55078    78.63672  ]
#    [ 57.32422    60.82422    41.83203  ]
#    [ 86.28906    87.28906    70.875    ]]
#
#   [[ 60.51172    70.51172    61.30078  ]
#    [ 54.29297    64.90625    51.82422  ]
#    [ 64.40625    75.76953    57.808594 ]
#    ...
#    [100.52344   104.66797    80.82031  ]
#    [ 77.46094    79.71875    56.621094 ]
#    [ 70.23828    71.26953    48.30078  ]]
#
#   [[ 61.03125    72.03125    56.460938 ]
#    [ 66.125      77.125      60.76953  ]
#    [ 74.0625     86.0625     66.0625   ]
#    ...
#    [101.78516   104.78516    77.78516  ]
#    [ 71.87109    74.87109    45.871094 ]
#    [ 92.32422    95.60547    65.75391  ]]
#
#   ...
#
#   [[ 57.878906   63.234375   51.73047  ]
#    [ 67.25781    74.25781    66.50781  ]
#    [ 59.984375   66.40625    63.765625 ]
#    ...
#    [ 72.95703    73.30469    58.621094 ]
#    [ 89.89453    92.53125    72.38281  ]
#    [ 75.73828   110.07031    93.17969  ]]
#
#   [[ 75.99219    80.35547    78.78125  ]
#    [ 54.558594   65.1875     53.05078  ]
#    [ 42.046875   56.84375    43.015625 ]
#    ...
#    [ 61.253906   80.84766    45.148438 ]
#    [ 69.51953    89.71875    53.898438 ]
#    [ 91.5       105.40625    76.08594  ]]
#
#   [[ 78.109375   80.19531    75.35156  ]
#    [ 97.47656   108.67578    91.46094  ]
#    [ 84.90625   101.53516    82.18359  ]
#    ...
#    [109.75781   132.25781    94.25781  ]
#    [ 95.06641   117.56641    79.56641  ]
#    [123.640625  134.64062   103.140625 ]]]
#
#
#  [[[ 49.1709     71.33984    83.73047  ]
#    [ 85.00391    96.74512   126.38574  ]
#    [ 90.52051    95.081055  134.70801  ]
#    ...
#    [207.39551   234.68945   251.24707  ]
#    [182.05371   210.47754   229.44629  ]
#    [193.93848   226.53809   246.39746  ]]
#
#   [[ 46.13672    68.87109    55.32422  ]
#    [ 59.708984   72.00098    78.11035  ]
#    [ 69.06055    74.70703   101.225586 ]
#    ...
#    [205.80664   235.61914   241.16992  ]
#    [181.82715   218.1914    234.23828  ]
#    [193.77441   234.76562   250.10254  ]]
#
#   [[ 70.21875    87.04785    83.0625   ]
#    [ 63.780273   71.57129    82.083984 ]
#    [ 79.069336   82.91211   110.50586  ]
#    ...
#    [186.4336    214.1377    215.51172  ]
#    [168.59766   211.1289    224.86328  ]
#    [182.04199   228.88574   241.46387  ]]
#
#   ...
#
#   [[ 54.401367   61.054688   60.899414 ]
#    [ 45.78418    46.64746    48.43164  ]
#    [ 55.29004    49.109375   55.74414  ]
#    ...
#    [ 73.34863    78.703125   71.86426  ]
#    [ 66.50195    71.37402    68.44629  ]
#    [ 62.35742    66.58984    64.634766 ]]
#
#   [[ 45.29883    44.98633    44.36133  ]
#    [ 46.421875   46.421875   46.421875 ]
#    [ 47.96289    47.663086   51.5      ]
#    ...
#    [ 64.40234    71.34277    65.46484  ]
#    [ 61.98535    70.583984   69.00586  ]
#    [ 66.05762    69.23633    73.524414 ]]
#
#   [[ 43.84668    42.84668    40.84668  ]
#    [ 40.039062   40.039062   40.039062 ]
#    [ 34.6416     35.6416     37.6416   ]
#    ...
#    [ 63.63672    69.96484    66.29297  ]
#    [ 63.98242    73.45117    74.83301  ]
#    [ 65.86914    70.02539    75.66016  ]]]], shape=(256, 32, 32, 3), dtype=float32)
#
#
#
# tf.Tensor(
# [34 19 20 21 38 25 38 23  2 34  0 14 39 17  1 18 24 17 29 17 18 32  9 32
#   4 27 30 25 37 34 29 30 41  5 28 37 31  8 33 13 10  8 24  4 33 36 31 20
#  20 29 28  9  4 11 42 15 26 16 16  2 17 32 28  5  4  3 42 32 31 17 22 29
#  34 30 24 27 32 19 27 22  6 26 21 33 32 10 16 20 12 22 32 37 33 20  3 30
#  11 21  4 14 35 26 17 29 29 16  2 16 31 31 29 19 42 23  7 28  8 24 40 30
#   0 33  7 19  6 11 37 28 25  3 32 33 42 16 22 10 36 33 27 27 37 34 19 22
#  20 42 12 32 42 32 40 21 34 34  2 11 29 10 31  2 11 19 15  5 13 42 20 37
#   7 37 10  7 35 25 34 23 24 33 39 28  9 12 21 10 18 22 23 36 19  0 37 10
#  38  7 39 37 12 21  9 36  9 26 26 31 10  0 34 24  5 25 38 10 14 24 33 37
#  33 21 13  6 33 29 17 18 35 31 12 21  1 17 26  7 12 25 39 33 31  5 25 41
#  26 33  6  3  9 25 40  2  8 14  7 30 25  5 38 37], shape=(256,), dtype=int32)
#
#
# round 3
# tf.Tensor(
# [[[[  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    ...
#    [  6.703125    6.703125    8.703125 ]
#    [  6.703125    6.703125    8.703125 ]
#    [  6.703125    6.703125    8.703125 ]]
#
#   [[  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    ...
#    [  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    [  6.          6.          8.       ]]
#
#   [[  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    [  6.          6.          8.       ]
#    ...
#    [  5.515625    5.515625    7.515625 ]
#    [  5.515625    5.515625    7.515625 ]
#    [  5.515625    5.515625    7.515625 ]]
#
#   ...
#
#   [[  9.515625    9.515625   11.515625 ]
#    [ 14.343262   17.280762   22.187012 ]
#    [ 27.721191   28.721191   30.721191 ]
#    [ 12.608887   16.608887   19.608887 ]]
#
#   ...
#
#   [[  8.890625    8.890625   10.890625 ]
#    [  9.586426    9.586426   11.586426 ]
#    [  8.027832    8.027832   10.027832 ]
#    ...
#    [ 10.671875   10.671875   12.671875 ]
#    [  9.78125     9.78125    11.78125  ]
#    [  8.890625    8.890625   10.890625 ]]
#
#   [[  8.          8.         10.       ]
#    [  8.          8.         10.       ]
#    [  8.          8.         10.       ]
#    ...
#    [  9.          9.         11.       ]
#    [  9.          9.         11.       ]
#    [  9.          9.         11.       ]]
#
#   [[  8.          8.         10.       ]
#    [  8.          8.         10.       ]
#    [  8.          8.         10.       ]
#    ...
#    [  9.421875    9.421875   11.421875 ]
#    [  9.421875    9.421875   11.421875 ]
#    [  9.421875    9.421875   11.421875 ]]]
#
#
#  ...
#
#
#  [[[255.        255.        251.       ]
#    [255.        255.        253.       ]
#    [255.        255.        255.       ]
#    ...
#    [239.4414    251.625     253.16797  ]
#    [184.98047   205.79297   208.58203  ]
#    [191.79297   221.23438   224.23438  ]]
#
#   [[255.        255.        253.       ]
#    [255.        255.        253.       ]
#    [255.        255.        255.       ]
#    ...
#    [245.625     254.3125    255.       ]
#    [230.8125    245.16016   247.26562  ]
#    [223.875     247.30078   248.73828  ]]
#
#   [[255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        253.       ]
#    ...
#    [252.67969   255.        255.       ]
#    [244.47656   252.46484   252.96484  ]
#    [236.5       250.41797   250.66797  ]]
#
#   ...
#
#   [[176.91797   234.26953   248.75     ]
#    [175.30469   235.6914    253.36719  ]
#    [174.15234   234.1875    255.       ]
#    ...
#    [121.97266   150.82031   209.76562  ]
#    [139.44531   168.50781   233.89062  ]
#    [ 92.25      125.10156   190.875    ]]
#
#   [[182.55078   227.98828   254.64844  ]
#    [178.125     230.21484   255.       ]
#    [171.80469   226.73828   254.4961   ]
#    ...
#    [104.98047   130.53516   188.33984  ]
#    [136.40234   165.82031   225.33984  ]
#    [ 91.27344   124.22266   173.64844  ]]
#
#   [[184.3164    224.75      255.       ]
#    [180.08594   228.17578   255.       ]
#    [169.875     222.39844   253.95703  ]
#    ...
#    [121.75781   147.19531   202.88281  ]
#    [150.47656   180.30078   234.70312  ]
#    [ 97.85156   133.10156   167.59766  ]]]
#
#
#  [[[239.59766   255.        239.84766  ]
#    [246.0293    255.        243.90234  ]
#    [247.73047   250.60547   242.30664  ]
#    ...
#    [252.88672   246.5332    254.80469  ]
#    [247.41406   248.4082    253.24219  ]
#    [241.12305   247.38281   252.46094  ]]
#
#   [[241.19336   252.1289    246.41016  ]
#    [244.13281   251.43164   247.20703  ]
#    [254.17969   254.79492   252.99219  ]
#    ...
#    [249.76953   249.31055   251.14453  ]
#    [247.88867   251.88281   250.93945  ]
#    [247.20117   254.13867   252.82617  ]]
#
#   [[251.90039   253.88672   255.       ]
#    [253.08984   253.78125   255.       ]
#    [253.77734   252.55273   254.82422  ]
#    ...
#    [251.38086   254.91211   249.82422  ]
#    [248.0293    255.        246.47852  ]
#    [247.91016   255.        246.10156  ]]
#
#   ...
#
#   [[ 97.45117    78.01758    36.339844 ]
#    [ 96.009766   77.90625    34.927734 ]
#    [109.61719    92.60547    46.91797  ]
#    ...
#    [208.5293    160.74219   154.63477  ]
#    [ 93.53125    49.23633    38.476562 ]
#    [ 62.65625    32.76367    28.423828 ]]
#
#   [[ 82.98047    68.32422    28.324219 ]
#    [ 94.66797    80.57422    37.24414  ]
#    [100.16992    86.51367    40.304688 ]
#    ...
#    [226.57031   185.9336    167.49805  ]
#    [102.86719    63.160156   43.279297 ]
#    [ 68.91016    42.154297   28.308594 ]]
#
#   [[ 81.41406    68.3418     32.382812 ]
#    [ 94.06055    81.74609    41.154297 ]
#    [101.8457     88.89453    44.054688 ]
#    ...
#    [245.32617   212.47852   183.01953  ]
#    [116.93945    80.72656    51.125    ]
#    [ 80.634766   56.916016   36.009766 ]]]
#
#
#  [[[ 43.59082    36.59082    18.71582  ]
#    [ 74.08887    66.86621    49.26367  ]
#    [ 96.93359    85.100586   73.27246  ]
#    ...
#    [ 39.59375    43.322266   42.166016 ]
#    [ 44.35254    48.22754    47.22754  ]
#    [ 41.61035    41.6709     41.655273 ]]
#
#   [[ 62.645508   55.841797   40.213867 ]
#    [ 88.34473    82.04785    66.37598  ]
#    [103.34668    95.96973    83.362305 ]
#    ...
#    [ 36.450195   38.075195   37.106445 ]
#    [ 37.59082    39.21582    38.40332  ]
#    [ 34.30371    34.3291     34.316406 ]]
#
#   [[ 70.362305   65.0293     51.63867  ]
#    [ 85.69629    83.00586    68.74219  ]
#    [ 92.50391    89.75391    77.856445 ]
#    ...
#    [ 35.953125   35.35254    35.484375 ]
#    [ 32.137695   31.512695   31.825195 ]
#    [ 31.323242   31.313477   31.31836  ]]
#
#   ...
#
#   [[ 36.573242   35.958008   37.640625 ]
#    [ 33.3125     33.283203   34.67285  ]
#    [ 33.654297   33.078125   34.79004  ]
#    ...
#    [ 35.50293    38.086914   40.600586 ]
#    [ 40.405273   40.5791     43.499023 ]
#    [ 40.99414    40.379883   41.348633 ]]
#
#   [[ 34.353516   34.353516   36.353516 ]
#    [ 33.038086   33.038086   35.038086 ]
#    [ 34.2666     34.2666     36.2666   ]
#    ...
#    [ 33.938477   37.938477   38.938477 ]
#    [ 39.72754    40.868164   42.82129  ]
#    [ 41.78418    41.799805   41.831055 ]]
#
#   [[ 32.124023   32.124023   34.124023 ]
#    [ 32.197266   32.197266   34.197266 ]
#    [ 35.479492   35.479492   37.479492 ]
#    ...
#    [ 33.765625   37.765625   38.765625 ]
#    [ 38.825195   39.96582    41.918945 ]
#    [ 42.876953   42.89258    42.92383  ]]]], shape=(256, 32, 32, 3), dtype=float32)
#
#
#
# tf.Tensor(
# [ 5  5  7  7 21 23  8 21 12 35 12  9  5 11 21 35  6  7  0 37  2  3  7 18
#  26 17  0  7 13 20  1  1 14  0 41 21  6 33 37 22 12 16 13 29 18 40  4 29
#  22 15  0 16 11  0 22  4  8 13  5 23 28  8  8  4 40 32 30 14 27  6 41 18
#  13  0  7 10 31 41 20 17 29 35 11 37 36 15 23 12 22 19 16  7 11 12 25 23
#   9 29 30 36 13  6 38 25 29 23 18 32 40 35 14  8  6 29 41 26 11 26 18 10
#   2  7 12  8 42 25 26 10  1 26 23 35 40 23 13 37 23  8 30 11 20 27 41 40
#   3  2 31 22 34  8 29 20 18 21 35  1 18 31 20 24 14  9 29 28 39 14 11 27
#  38 40 39 24  7 12 19 21 17 33 32 31 11 29  0 14  1  2 29 31  2  0 10  2
#  16 42 18 34 41 10 32  0 16 42  0 30 30  3 17 26 12  7 10 14  9 34 25 25
#  25 10 38 24 12 19  2  6 36 24 10 23 18  2 31 20 15 10  1 20 10 21 16 19
#   4 39 22  6  0 17 32 36 19 28 38 31 25 16 35  1], shape=(256,), dtype=int32)
#
#
# round 4
# tf.Tensor(
# [[[[ 12.        16.        17.      ]
#    [ 12.        16.        17.      ]
#    [ 13.75      15.125     17.      ]
#    ...
#    [ 16.        15.        20.      ]
#    [ 16.        15.        20.      ]
#    [ 16.        15.        20.      ]]
#
#   [[ 12.        16.        17.      ]
#    [ 12.        16.        17.      ]
#    [ 13.75      15.125     17.      ]
#    ...
#    [ 16.        15.        20.      ]
#    [ 16.        15.        20.      ]
#    [ 16.        15.        20.      ]]
#
#   [[ 12.        16.        17.      ]
#    [ 12.        16.        17.      ]
#    [ 13.75      15.125     17.      ]
#    ...
#    [ 16.        15.        20.      ]
#    [ 16.        15.        20.      ]
#    [ 16.        15.        20.      ]]
#
#   ...
#
#   [[ 14.        14.        16.      ]
#    [ 14.        14.        16.      ]
#    [ 14.        14.        16.      ]
#    ...
#    [  9.712891  13.890625  16.890625]
#    [  8.837891  13.015625  16.015625]
#    [  9.685547  13.8125    16.8125  ]]
#
#   [[ 13.078125  13.078125  15.078125]
#    [ 13.078125  13.078125  15.078125]
#    [ 13.078125  13.078125  15.078125]
#    ...
#    [  8.621094  16.03125   18.22461 ]
#    [  8.552734  15.962891  18.15625 ]
#    [  9.033203  15.732422  18.15625 ]]
#
#   [[ 13.        13.        15.      ]
#    [ 13.        13.        15.      ]
#    [ 13.        13.        15.      ]
#    ...
#    [ 23.94336   34.414062  36.09961 ]
#    [ 29.617188  40.08789   41.773438]
#    [ 33.978516  44.109375  45.884766]]]
#
#
#  [[[151.65625  165.65625  192.65625 ]
#    [151.65625  165.65625  192.65625 ]
#    [151.65625  165.65625  192.65625 ]
#    ...
#    [151.26562  166.26562  189.26562 ]
#    [149.76904  164.76904  187.76904 ]
#    [148.46582  163.46582  186.46582 ]]
#
#   [[149.96875  163.96875  189.96875 ]
#    [149.96875  163.96875  189.96875 ]
#    [149.96875  163.96875  189.96875 ]
#    ...
#    [146.01562  161.01562  184.01562 ]
#    [146.99463  161.99463  184.99463 ]
#    [148.60938  163.60938  186.60938 ]]
#
#   [[148.28125  162.28125  188.28125 ]
#    [148.28125  162.28125  188.28125 ]
#    [148.28125  162.28125  188.28125 ]
#    ...
#    [ 48.930664  53.29492   47.506836]
#    ...
#    [ 39.551758  41.551758  36.551758]
#    [ 37.816406  39.816406  34.816406]
#    [ 33.71875   34.71875   29.71875 ]]
#
#   [[ 58.33203   54.213867  53.26367 ]
#    [ 42.884766  42.023438  40.04785 ]
#    [ 55.432617  56.402344  51.432617]
#    ...
#    [ 62.307617  64.30762   59.307617]
#    [ 53.930664  55.930664  50.930664]
#    [ 40.34375   41.34375   36.34375 ]]
#
#   ...
#
#   [[ 27.331055  25.331055  13.331055]
#    [ 28.90625   25.90625   16.90625 ]
#    [ 30.030273  27.030273  22.030273]
#    ...
#    [ 33.875977  32.875977  27.875977]
#    [ 35.6875    34.6875    29.6875  ]
#    [ 29.0625    28.0625    23.0625  ]]
#
#   [[ 31.536133  29.536133  17.536133]
#    [ 38.17285   35.17285   26.172852]
#    [ 35.676758  32.676758  27.676758]
#    ...
#    [ 34.26758   33.26758   28.267578]
#    [ 33.0459    32.0459    27.045898]
#    [ 25.4375    24.4375    19.4375  ]]
#
#   [[ 36.77246   34.77246   22.77246 ]
#    [ 47.197266  44.197266  35.197266]
#    [ 35.149414  32.149414  27.149414]
#    ...
#    [ 29.78125   28.78125   23.78125 ]
#    [ 30.625     29.625     24.625   ]
#    [ 30.        29.        24.      ]]]], shape=(256, 32, 32, 3), dtype=float32)
#
#
#
# tf.Tensor(
# [10 20  9 17 18  9  4 41  1 29  2  3  8 21 20 35 33 13 17 21 38 17 41 13
#  32  9 15 32 39 26 42 31 26 10 12 14 39 18 30 20 15  6 39 23 40  7 35  9
#  23 31 39 34 35 29 27 30 16  4 22 12 10 15  8  5 15 19 22 16 23 40 37 32
#  22 26 13 13 26 31  6 32 37 24 23 27 38 35 41 11 14  1 13  1 18 31 34 20
#  10  8 37 22 11 34 27 36 18  9 30 30  1 25 19 15 28 36 14 40 40 16 24 14
#   5 10 19 29 11 22 38 33 29 26  8 36 22  4 35 24 13 32 11 35 17 28 25 16
#  30 11 36 14 16  0  7 36 33  5  2 32 34 39 20 35 14 21  9  3  1 37  1  1
#  31 20 41  7 11 28  8  4 17 42 38 30 37 36 32  2 38  3 40 16 13 12 19 24
#  28 15 15 18  5 38 12  3  0 14 19 20 25 14 14  0 23  8 28 37 11  7 10 22
#  28 13  8 19  4 41  0  9  8 24 13 32  7 38 23 16 36 39 31 41 15 24 42 12
#   5 17 30  5  9 41 21 37 18 13 24 30  1 38 15  2], shape=(256,), dtype=int32)
#
#
# round 5
# tf.Tensor(
# [[[[252.29688  247.29688  228.29688 ]
#    [252.04639  246.20264  229.73389 ]
#    [252.28564  246.28564  231.09814 ]
#    ...
#    [222.49902  192.83838  190.67334 ]
#    [220.2334   190.32764  177.96729 ]
#    [138.64404  118.69678   87.84717 ]]
#
#   [[253.       247.10938  230.78125 ]
#    [252.90771  246.9248   230.87354 ]
#    [251.63818  245.63818  230.45068 ]
#    ...
#    [212.93652  196.68652  192.7959  ]
#    [216.36035  194.32666  188.6372  ]
#    [181.3999   157.38623  148.63379 ]]
#    [ 39.53125   41.53125   38.0625  ]
#    [ 37.578125  39.4375    34.4375  ]
#    [ 35.        36.        31.      ]]]
#
#
#  [[[255.       255.       255.      ]
#    [255.       255.       255.      ]
#    [255.       255.       255.      ]
#    ...
#    [ 32.628906  32.628906  32.628906]
#    [ 27.902344  27.902344  27.902344]
#    [ 31.359375  31.359375  31.359375]]
#
#   [[255.       255.       255.      ]
#    [255.       255.       255.      ]
#    [255.       255.       255.      ]
#    ...
#    [ 29.96875   29.96875   29.96875 ]
#    [ 28.083984  28.083984  28.083984]
#    [ 32.291016  32.291016  32.291016]]
#
#   [[255.       255.       255.      ]
#    [255.       255.       255.      ]
#    [255.       255.       255.      ]
#    ...
#    [ 28.625     28.625     28.625   ]
#    [ 28.683594  28.683594  28.683594]
#    [ 31.554688  31.554688  31.554688]]
#
#   ...
#
#   [[255.       253.64648  253.61523 ]
#    [248.42578  249.79102  247.89453 ]
#    [240.42773  245.54297  241.71289 ]
#    ...
#    [ 30.269531  31.269531  26.269531]
#    [ 28.853516  29.853516  24.853516]
#    [ 30.447266  31.447266  26.447266]]
#
#   [[249.96094  245.81055  245.35742 ]
#    [232.76953  231.33594  229.63281 ]
#    [215.44531  219.02148  214.8086  ]
#    ...
#    [ 27.720703  28.720703  23.720703]
#    [ 25.435547  26.435547  21.435547]
#    [ 25.59961   26.59961   21.59961 ]]
#
#   [[231.46875  224.04883  222.14258 ]
#    [205.5293   202.13867  198.98242 ]
#    [190.05078  191.17188  186.56055 ]
#    ...
#    [ 31.552734  32.552734  27.552734]
#    [ 30.791016  31.791016  26.791016]
#    [ 31.904297  32.904297  27.904297]]]], shape=(30, 32, 32, 3), dtype=float32)
#
#
#
# tf.Tensor(
# [12  3 30 12  9 39 22 22 28 13  8 13  2 37 13  0  9  7 33 22 20 25  4 13
#  10 40 22 19  2 22], shape=(30,), dtype=int32)

# %%
(32**2) * 3
# Out:
# 3072

# %%
i = 1
print(f"is {i}"), print('is {}'.format(i))
# Out:
# is 1
# is 1
# (None, None)

# %%
a = []
a.append([3, 4])
a
# Out:
# [[3, 4]]

# %%
import argparse
import logging

import tensorflow as tf

from dataset import get_datasets
# from logistic import softmax, cross_entropy, accuracy


def get_module_logger(mod_name):
    logger = logging.getLogger(mod_name)
    handler = logging.StreamHandler()
    formatter = logging.Formatter('%(asctime)s %(levelname)-8s %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)
    logger.setLevel(logging.DEBUG)
    return logger

def softmax(logits):
    """
    softmax implementation
    args:
    - logits [tensor]: 1xN logits tensor
    returns:
    - soft_logits [tensor]: softmax of logits
    """
    # IMPLEMENT THIS FUNCTION
    logits_exp = tf.math.exp(logits)
      
    # remember to use axis=1
    logits_sum = tf.math.reduce_sum(logits_exp, axis=1, keepdims=True)
#     print('logits_sum {}'.format(logits_sum))
    
    soft_logits = logits_exp / logits_sum
    return soft_logits

def model(X, W, b):
    """
    logistic regression model
    args:
    - X [tensor]: input HxWx3
    - W [tensor]: weights
    - b [tensor]: bias
    returns:
    - output [tensor]
    """
    # IMPLEMENT THIS FUNCTION
    X_flatten = tf.reshape(X, [-1,  W.shape[0]])
    logits = tf.matmul(X_flatten, W) + b
    output_probs = softmax(logits)
    return output_probs

def cross_entropy(scaled_logits, one_hot):
    """
    Cross entropy loss implementation
    args:
    - scaled_logits [tensor]: NxC tensor where N batch size / C number of classes
    - one_hot [tensor]: NxC one hot tensor
    returns:
    - loss [tensor]: cross entropy 
    """
    # IMPLEMENT THIS FUNCTION
    masked_prob = tf.boolean_mask(scaled_logits, one_hot)
    cross_entropy_val = -1 * tf.math.log(masked_prob)
    return cross_entropy_val

def accuracy(y_hat, Y):
    """
    calculate accuracy
    args:
    - y_hat [tensor]: NxC tensor of models predictions
    - y [tensor]: N tensor of ground truth classes
    returns:
    - acc [tensor]: accuracy
    """
    # IMPLEMENT THIS FUNCTION
    pred_class = tf.cast(tf.argmax(y_hat, axis=1), Y.dtype)
    compare_result = tf.cast(pred_class == Y, tf.int32)
    acc = tf.math.reduce_sum(compare_result) / Y.shape[0]
    return acc

def sgd(params, grads, lr, bs):
    """
    stochastic gradient descent implementation
    args:
    - params [list[tensor]]: model params
    - grad [list[tensor]]: param gradient such that params[0].shape == grad[0].shape
    - lr [float]: learning rate
    - bs [int]: batch_size
    """
    # IMPLEMENT THIS FUNCTION
#     print('\n\n params', params)  # [W, b]  
#     print('\n\n grads', grads)    # [W_grad, b_grad]
    
    i = -1
    for param, grad in zip(params, grads):
        i += 1
#         print('\n\n element {}'.format(i))
#         print('\n\n param', param)    
#         print('\n\n grad', grad)

        param.assign_sub( lr * grad / bs)
    
def training_loop(train_dataset, model, W, b, optimizer):
    """
    training loop
    args:
    - train_dataset: 
    - model [func]: model function
    - loss [func]: loss function
    - optimizer [func]: optimizer func
    returns:
    - mean_loss [tensor]: mean training loss
    - mean_acc [tensor]: mean training accuracy
    """
    losses = []
    accuracies = []
    i = -1
    for X, Y in train_dataset:  # get one batch in multiple batches
        i += 1
#         print('batch {}'.format(i))
        
        with tf.GradientTape() as tape:
            # IMPLEMENT THIS FUNCTION
            X = X / 255.0
            Y_hat = model(X, W, b)
            
            Y_one_hot = tf.one_hot(Y, 43)            
            loss = cross_entropy(Y_hat, Y_one_hot)
#             print('loss {}'.format(loss))
                        
            losses.append(tf.math.reduce_mean(loss))

            acc = accuracy(Y_hat, Y)
            accuracies.append(acc)
            
            grads = tape.gradient(loss, [W, b]) # grads = [W_grad, b_grad]

            lr = 0.1
            optimizer([W, b], grads, lr, X.shape[0])
            
    mean_loss = tf.math.reduce_mean(losses)
    mean_acc = tf.math.reduce_mean(tf.concat(accuracies, axis=0))
    
    return mean_loss, mean_acc


def validation_loop(val_dataset, model, W, b):
    """
    training loop
    args:
    - train_dataset: 
    - model [func]: model function
    - loss [func]: loss function
    - optimizer [func]: optimizer func
    returns:
    - mean_acc [tensor]: mean validation accuracy
    """
    # IMPLEMENT THIS FUNCTION
    accuracies = []
    i = -1
    for X, Y in val_dataset:  # get one batch in multiple batches
        i += 1
#         print('\n\n batch {}'.format(i))
        
        X = X / 255.0
        Y_hat = model(X, W, b)
        
        acc = accuracy(Y_hat, Y)
        accuracies.append(acc)
            
    mean_acc = tf.math.reduce_mean(tf.concat(accuracies, axis=0))    
    return mean_acc


if __name__  == '__main__':
#     logger = get_module_logger(__name__)
#     parser = argparse.ArgumentParser(description='Download and process tf files')
#     parser.add_argument('--imdir', required=True, type=str,
#                         help='data directory')
#     parser.add_argument('--epochs', default=10, type=int,
#                         help='Number of epochs')
#     args = parser.parse_args()    
# 
#     logger.info(f'Training for {args.epochs} epochs using {args.imdir} data')
    
    epochs = 100
    imdir = 'GTSRB/Final_Training/Images'
              
    print(f'Training for {epochs} epochs using {imdir} data')
        
              
    # get the datasets
    train_dataset, val_dataset = get_datasets(imdir)

    # set the variables
    num_inputs = (32**2) *3  # image is resized in get_datasets() above as 32 * 32
    num_outputs = 43 # 43 classes
    
    W = tf.Variable(
        tf.random.normal(
            shape=(num_inputs, num_outputs),
            mean=0,
            stddev=0.01
        )
    )
    b = tf.Variable(
        tf.zeros(num_outputs)
    )

    # training! 
    for epoch in range(epochs):
        print(f'\nEpoch {epoch}')
        
        loss, acc = training_loop(train_dataset, model, W, b, sgd)        
        print(f'Mean training loss: {loss:1f}, mean training accuracy {acc:1f}')
        
        acc = validation_loop(val_dataset, model, W, b)
        print(f'Mean validation accuracy {acc:1f}')
# Out:
# Training for 100 epochs using GTSRB/Final_Training/Images data
# Found 4300 files belonging to 43 classes.
# Using 3870 files for training.
# Found 4300 files belonging to 43 classes.
# Using 430 files for validation.
#
# Epoch 0
# Mean training loss: 3.634902, mean training accuracy 0.072428
# Mean validation accuracy 0.033787
#
# Epoch 1
# Mean training loss: 3.495463, mean training accuracy 0.163021
# Mean validation accuracy 0.031026
#
# Epoch 2
# Mean training loss: 3.556461, mean training accuracy 0.256950
# Mean validation accuracy 0.040454
#
# Epoch 3
# Mean training loss: 3.189094, mean training accuracy 0.287907
# Mean validation accuracy 0.057000
#
# Epoch 4
# Mean training loss: 2.927907, mean training accuracy 0.367057
# Mean validation accuracy 0.161683
#
# Epoch 5
# Mean training loss: 2.541489, mean training accuracy 0.440820
# Mean validation accuracy 0.231681
#
# Epoch 6
# Mean training loss: 2.465732, mean training accuracy 0.476074
# Mean validation accuracy 0.180765
#
# Epoch 7
# Mean training loss: 2.415739, mean training accuracy 0.525553
# Mean validation accuracy 0.237069
#
# Epoch 8
# Mean training loss: 2.241125, mean training accuracy 0.530794
# Mean validation accuracy 0.345434
#
# Epoch 9
# Mean training loss: 2.165295, mean training accuracy 0.576270
# Mean validation accuracy 0.339911
#
# Epoch 10
# Mean training loss: 2.089894, mean training accuracy 0.587305
# Mean validation accuracy 0.256600
#
# Epoch 11
# Mean training loss: 2.039212, mean training accuracy 0.614551
# Mean validation accuracy 0.372328
#
# Epoch 12
# Mean training loss: 1.950839, mean training accuracy 0.632617
# Mean validation accuracy 0.423469
#
# Epoch 13
# Mean training loss: 1.894412, mean training accuracy 0.658040
# Mean validation accuracy 0.525862
#
# Epoch 14
# Mean training loss: 1.856340, mean training accuracy 0.672282
# Mean validation accuracy 0.477011
#
# Epoch 15
# Mean training loss: 1.820117, mean training accuracy 0.681559
# Mean validation accuracy 0.529881
#
# Epoch 16
# Mean training loss: 1.742172, mean training accuracy 0.692057
# Mean validation accuracy 0.379221
#
# Epoch 17
# Mean training loss: 1.767691, mean training accuracy 0.686068
# Mean validation accuracy 0.473217
#
# Epoch 18
# Mean training loss: 1.712877, mean training accuracy 0.698893
# Mean validation accuracy 0.550445
#
# Epoch 19
# Mean training loss: 1.644615, mean training accuracy 0.734342
# Mean validation accuracy 0.466101
#
# Epoch 20
# Mean training loss: 1.648006, mean training accuracy 0.715999
# Mean validation accuracy 0.489314
#
# Epoch 21
# Mean training loss: 1.631853, mean training accuracy 0.729818
# Mean validation accuracy 0.567798
#
# Epoch 22
# Mean training loss: 1.565240, mean training accuracy 0.747510
# Mean validation accuracy 0.448747
#
# Epoch 23
# Mean training loss: 1.564085, mean training accuracy 0.729541
# Mean validation accuracy 0.493916
#
# Epoch 24
# Mean training loss: 1.522367, mean training accuracy 0.746761
# Mean validation accuracy 0.555271
#
# Epoch 25
# Mean training loss: 1.507350, mean training accuracy 0.762305
# Mean validation accuracy 0.676387
#
# Epoch 26
# Mean training loss: 1.451800, mean training accuracy 0.780583
# Mean validation accuracy 0.642376
#
# Epoch 27
# Mean training loss: 1.429610, mean training accuracy 0.779118
# Mean validation accuracy 0.572288
#
# Epoch 28
# Mean training loss: 1.426221, mean training accuracy 0.772412
# Mean validation accuracy 0.659281
#
# Epoch 29
# Mean training loss: 1.376057, mean training accuracy 0.786719
# Mean validation accuracy 0.638358
#
# Epoch 30
# Mean training loss: 1.377653, mean training accuracy 0.787777
# Mean validation accuracy 0.653870
#
# Epoch 31
# Mean training loss: 1.374534, mean training accuracy 0.792399
# Mean validation accuracy 0.668126
#
# Epoch 32
# Mean training loss: 1.335198, mean training accuracy 0.802946
# Mean validation accuracy 0.655487
#
# Epoch 33
# Mean training loss: 1.334560, mean training accuracy 0.797168
# Mean validation accuracy 0.650076
#
# Epoch 34
# Mean training loss: 1.314580, mean training accuracy 0.798519
# Mean validation accuracy 0.662267
#
# Epoch 35
# Mean training loss: 1.284792, mean training accuracy 0.807471
# Mean validation accuracy 0.584231
#
# Epoch 36
# Mean training loss: 1.275940, mean training accuracy 0.810514
# Mean validation accuracy 0.717650
#
# Epoch 37
# Mean training loss: 1.239418, mean training accuracy 0.826774
# Mean validation accuracy 0.674322
#
# Epoch 38
# Mean training loss: 1.233532, mean training accuracy 0.823340
# Mean validation accuracy 0.670999
#
# Epoch 39
# Mean training loss: 1.227766, mean training accuracy 0.825895
# Mean validation accuracy 0.627223
#
# Epoch 40
# Mean training loss: 1.225348, mean training accuracy 0.818197
# Mean validation accuracy 0.697535
#
# Epoch 41
# Mean training loss: 1.193281, mean training accuracy 0.834196
# Mean validation accuracy 0.699264
#
# Epoch 42
# Mean training loss: 1.171185, mean training accuracy 0.836019
# Mean validation accuracy 0.708805
#
# Epoch 43
# Mean training loss: 1.177972, mean training accuracy 0.835026
# Mean validation accuracy 0.725575
#
# Epoch 44
# Mean training loss: 1.158887, mean training accuracy 0.840169
# Mean validation accuracy 0.645137
#
# Epoch 45
# Mean training loss: 1.156743, mean training accuracy 0.835286
# Mean validation accuracy 0.587217
#
# Epoch 46
# Mean training loss: 1.150192, mean training accuracy 0.820752
# Mean validation accuracy 0.688690
#
# Epoch 47
# Mean training loss: 1.110446, mean training accuracy 0.851432
# Mean validation accuracy 0.721332
#
# Epoch 48
# Mean training loss: 1.119741, mean training accuracy 0.843945
# Mean validation accuracy 0.741783
#
# Epoch 49
# Mean training loss: 1.104506, mean training accuracy 0.853857
# Mean validation accuracy 0.716617
#
# Epoch 50
# Mean training loss: 1.087543, mean training accuracy 0.853841
# Mean validation accuracy 0.727999
#
# Epoch 51
# Mean training loss: 1.091979, mean training accuracy 0.856299
# Mean validation accuracy 0.716617
#
# Epoch 52
# Mean training loss: 1.086000, mean training accuracy 0.851025
# Mean validation accuracy 0.713744
#
# Epoch 53
# Mean training loss: 1.071849, mean training accuracy 0.859603
# Mean validation accuracy 0.715585
#
# Epoch 54
# Mean training loss: 1.079382, mean training accuracy 0.847217
# Mean validation accuracy 0.661346
#
# Epoch 55
# Mean training loss: 1.091674, mean training accuracy 0.837549
# Mean validation accuracy 0.650548
#
# Epoch 56
# Mean training loss: 1.030366, mean training accuracy 0.859115
# Mean validation accuracy 0.756376
#
# Epoch 57
# Mean training loss: 1.018983, mean training accuracy 0.869727
# Mean validation accuracy 0.705819
#
# Epoch 58
# Mean training loss: 1.016616, mean training accuracy 0.870345
# Mean validation accuracy 0.736957
#
# Epoch 59
# Mean training loss: 1.005054, mean training accuracy 0.867660
# Mean validation accuracy 0.734891
#
# Epoch 60
# Mean training loss: 1.026189, mean training accuracy 0.858838
# Mean validation accuracy 0.783383
#
# Epoch 61
# Mean training loss: 0.981700, mean training accuracy 0.879736
# Mean validation accuracy 0.734308
#
# Epoch 62
# Mean training loss: 0.995517, mean training accuracy 0.873014
# Mean validation accuracy 0.690306
#
# Epoch 63
# Mean training loss: 0.978889, mean training accuracy 0.873275
# Mean validation accuracy 0.792812
#
# Epoch 64
# Mean training loss: 0.985876, mean training accuracy 0.874235
# Mean validation accuracy 0.676275
#
# Epoch 65
# Mean training loss: 0.976903, mean training accuracy 0.868376
# Mean validation accuracy 0.730985
#
# Epoch 66
# Mean training loss: 0.984440, mean training accuracy 0.872119
# Mean validation accuracy 0.785111
#
# Epoch 67
# Mean training loss: 0.963143, mean training accuracy 0.876172
# Mean validation accuracy 0.739830
#
# Epoch 68
# Mean training loss: 0.951140, mean training accuracy 0.876058
# Mean validation accuracy 0.778668
#
# Epoch 69
# Mean training loss: 0.947163, mean training accuracy 0.887549
# Mean validation accuracy 0.766613
#
# Epoch 70
# Mean training loss: 0.941839, mean training accuracy 0.883870
# Mean validation accuracy 0.766837
#
# Epoch 71
# Mean training loss: 0.922589, mean training accuracy 0.882910
# Mean validation accuracy 0.744208
#
# Epoch 72
# Mean training loss: 0.917101, mean training accuracy 0.886198
# Mean validation accuracy 0.754535
#
# Epoch 73
# Mean training loss: 0.921303, mean training accuracy 0.880811
# Mean validation accuracy 0.739718
#
# Epoch 74
# Mean training loss: 0.905632, mean training accuracy 0.898796
# Mean validation accuracy 0.784415
#
# Epoch 75
# Mean training loss: 0.888852, mean training accuracy 0.890234
# Mean validation accuracy 0.701105
#
# Epoch 76
# Mean training loss: 0.926785, mean training accuracy 0.874333
# Mean validation accuracy 0.751549
#
# Epoch 77
# Mean training loss: 0.895532, mean training accuracy 0.891325
# Mean validation accuracy 0.793148
#
# Epoch 78
# Mean training loss: 0.872416, mean training accuracy 0.895492
# Mean validation accuracy 0.714664
#
# Epoch 79
# Mean training loss: 0.878034, mean training accuracy 0.890592
# Mean validation accuracy 0.758217
#
# Epoch 80
# Mean training loss: 0.876826, mean training accuracy 0.892432
# Mean validation accuracy 0.742008
#
# Epoch 81
# Mean training loss: 0.859812, mean training accuracy 0.893294
# Mean validation accuracy 0.748675
#
# Epoch 82
# Mean training loss: 0.858156, mean training accuracy 0.895117
# Mean validation accuracy 0.784640
#
# Epoch 83
# Mean training loss: 0.847535, mean training accuracy 0.900374
# Mean validation accuracy 0.794877
#
# Epoch 84
# Mean training loss: 0.859733, mean training accuracy 0.893766
# Mean validation accuracy 0.748451
#
# Epoch 85
# Mean training loss: 0.859687, mean training accuracy 0.895361
# Mean validation accuracy 0.746386
#
# Epoch 86
# Mean training loss: 0.842310, mean training accuracy 0.895003
# Mean validation accuracy 0.800624
#
# Epoch 87
# Mean training loss: 0.832295, mean training accuracy 0.900358
# Mean validation accuracy 0.789130
#
# Epoch 88
# Mean training loss: 0.826238, mean training accuracy 0.897559
# Mean validation accuracy 0.784079
#
# Epoch 89
# Mean training loss: 0.837334, mean training accuracy 0.897917
# Mean validation accuracy 0.785448
#
# Epoch 90
# Mean training loss: 0.827202, mean training accuracy 0.895833
# Mean validation accuracy 0.789354
#
# Epoch 91
# Mean training loss: 0.812080, mean training accuracy 0.902327
# Mean validation accuracy 0.783495
#
# Epoch 92
# Mean training loss: 0.819469, mean training accuracy 0.899870
# Mean validation accuracy 0.812343
#
# Epoch 93
# Mean training loss: 0.808985, mean training accuracy 0.908187
# Mean validation accuracy 0.778556
#
# Epoch 94
# Mean training loss: 0.820983, mean training accuracy 0.901449
# Mean validation accuracy 0.738573
#
# Epoch 95
# Mean training loss: 0.809514, mean training accuracy 0.903174
# Mean validation accuracy 0.797751
#
# Epoch 96
# Mean training loss: 0.796311, mean training accuracy 0.907813
# Mean validation accuracy 0.784303
#
# Epoch 97
# Mean training loss: 0.802323, mean training accuracy 0.906950
# Mean validation accuracy 0.786144
#
# Epoch 98
# Mean training loss: 0.780103, mean training accuracy 0.905485
# Mean validation accuracy 0.791420
#
# Epoch 99
# Mean training loss: 0.784512, mean training accuracy 0.909912
# Mean validation accuracy 0.792812
